# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Five Dimension Index (1990-2016, East Asia, NA).csv")
df
# Out:
#           Country  Year  Health Access Quality Index  \
# 0           China  1990                         42.6
# 1           China  1995                         47.6
# 2           China  2000                         53.3
# 3           China  2005                         62.0
# 4           China  2010                         71.3
# 5           China  2016                         77.9
# 6           Japan  1990                         80.9
# 7           Japan  1995                         83.9
# 8           Japan  2000                         86.9
# 9           Japan  2005                         90.2
# 10          Japan  2010                         92.3
# 11          Japan  2016                         94.1
# 12    South Korea  1990                         59.5
# 13    South Korea  1995                         71.2
# 14    South Korea  2000                         74.4
# 15    South Korea  2005                         83.0
# 16    South Korea  2010                         87.7
# ...

# %%
Dict = { 'China': { '1990':{},'1995':{},'2000':{} },
         'Japan': { '1990':{},'1995':{},'2000':{}}}

# %%
years = ['1990','1995','2000',"2005","2010","2016"]
country = ['China','Japan']
features = ['Health','CO2',"Civil"]

# %%
print(Dict)
# Out:
# {'China': {'1990': {}, '1995': {}, '2000': {}}, 'Japan': {'1990': {}, '1995': {}, '2000': {}}}

# %%
print(Dict)
# Out:
# {'2016': {'Japan': {}}}
