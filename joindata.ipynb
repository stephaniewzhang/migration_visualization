# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Five Dimension Index (1990-2016, East Asia, NA).csv")
df
# Out:
#           Country  Year  Health Access Quality Index  \
# 0           China  1990                         42.6
# 1           China  1995                         47.6
# 2           China  2000                         53.3
# 3           China  2005                         62.0
# 4           China  2010                         71.3
# 5           China  2016                         77.9
# 6           Japan  1990                         80.9
# 7           Japan  1995                         83.9
# 8           Japan  2000                         86.9
# 9           Japan  2005                         90.2
# 10          Japan  2010                         92.3
# 11          Japan  2016                         94.1
# 12    South Korea  1990                         59.5
# 13    South Korea  1995                         71.2
# 14    South Korea  2000                         74.4
# 15    South Korea  2005                         83.0
# 16    South Korea  2010                         87.7
# ...

# %%
Dict = { 
'China': { 'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{4} , 
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}} ,  
'Japan':{   'Healthcare Access and Quality Index': { },'Annual CO2 Emissionn':{}, 'Civil Liberty':{8} , 
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}},
'South Korea': { 'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{8}, 
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}},
'North Korea':{  'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{3}, 
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}},
'Taiwan':{  'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{9}, 
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}},
'Mongolia':{ 'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{8} , 
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}},
"United States":{   'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{9},
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}},
'Canada':{'Healthcare Access and Quality Index': {}, 'Annual CO2 Emission':{}, 'Civil Liberty':{9},
          'Human Development Index':{},'Average Life Expectancy':{},'Total population (millions)':{},'GDP per capita':{},'Gender Gap Index':{}}  }

# %%
df_2005 = df.loc[df['Year'] == 2005]
df_2005 = df_2005.reset_index()
df_2005
# Out:
#    index        Country  Year  Health Access Quality Index  \
# 0      3          China  2005                         62.0
# 1      9          Japan  2005                         90.2
# 2     15    South Korea  2005                         83.0
# 3     21    North Korea  2005                         47.8
# 4     27         Taiwan  2005                         78.0
# 5     33       Mongolia  2005                         47.2
# 6     39  United States  2005                         87.3
# 7     45         Canada  2005                         91.2
#
#    Annual CO2 emissions (per capita)  Civil Liberty Status  \
# 0                             4.4159                     6
# 1                            10.0554                     2
# 2                            10.2578                     2
# 3                             3.1342                     7
# 4                            11.7354                     1
# 5                             3.3936                     2
# ...

# %%
years = ['1990','1995','2000',"2005","2010","2016"]
country = ['China','Japan']
features = ['Healthcare Access and Quality Index','Annual CO2 Emission',"Civil Liberty", 
          'Human Development Index','Average Life Expectancy','Total population (millions)','GDP per capita','Gender Gap Index']

# %%
healthMax = max(df_2005['Health Access Quality Index'])
healthMin = min(df_2005['Health Access Quality Index'])
healthMax
# Out:
# 91.2

# %%
climateMax = max(df_2005['Annual CO2 emissions (per capita)'])
climateMin = min(df_2005['Annual CO2 emissions (per capita)'])
climateMax
# Out:
# 20.7954

# %%
hdiMax = max(df_2005['Human Development Index'])
hdiMin = min(df_2005['Human Development Index'])
hdiMax
# Out:
# 0.903

# %%
lifeMax = max(df_2005['Average Life Expectancy'])
lifeMin = min(df_2005['Average Life Expectancy'])
lifeMax
# Out:
# 81.93

# %%
popMax = max(df_2005['Total population (millions)'])
popMin = min(df_2005['Total population (millions)'])
popMax
# Out:
# 1315.8

# %%
gdpMax = max(df_2005['GDP per capita'])
gdpMin = min(df_2005['GDP per capita'])
gdpMax
# Out:
# 41399.0

# %%
genderGapMax = max(df_2005['Gender Gap Index'])
genderGapMin = min(df_2005['Gender Gap Index'])
genderGapMax
# Out:
# 0.716

# %%
def healthScale (n):
    return ((n - healthMin) * 10) / (healthMax-healthMin)

# %%
def climateScale (n):
    return ((n - climateMin) * 10) / (climateMax-climateMin)

# %%
def hdiScale (n):
    return ((n - hdiMin) * 10) / (hdiMax-hdiMin)

# %%
def lifeScale (n):
    return ((n - lifeMin) * 10) / (lifeMax-lifeMin)

# %%
def popScale (n):
    return ((n - popMin) * 10) / (popMax-popMin)

# %%
def gdpScale(n):
     return ((n - gdpMin) * 10) / (gdpMax-gdpMin)

# %%
def genderGapScale(n):
     return ((n - genderGapMin) * 10) / (genderGapMax-genderGapMin)

# %%
health_new = []
health_new = map( healthScale ,df_2005['Health Access Quality Index'] )
health_new = list(health_new)
health_new
# Out:
# [3.363636363636363,
#  9.772727272727273,
#  8.136363636363637,
#  0.13636363636363508,
#  7.0,
#  0.0,
#  9.113636363636362,
#  10.0]

# %%
df_2005['Health Access Quality Index']
# Out:
# 0    62.0
# 1    90.2
# 2    83.0
# 3    47.8
# 4    78.0
# 5    47.2
# 6    87.3
# 7    91.2
# Name: Health Access Quality Index, dtype: float64

# %%
climate_new = []
climate_new = map( climateScale ,df_2005['Annual CO2 emissions (per capita)'] )
climate_new = list(climate_new)

# %%
hdi_new = []
hdi_new = map( hdiScale ,df_2005['Human Development Index'] )
hdi_new = list(hdi_new)
hdi_new
# Out:
# [0.0,
#  9.471698113207546,
#  8.377358490566037,
#  nan,
#  nan,
#  0.41509433962264186,
#  9.88679245283019,
#  10.0]

# %%
life_new = []
life_new = map( lifeScale ,df_2005['Average Life Expectancy'] )
life_new = list(life_new)
life_new
# Out:
# [4.682115270350566,
#  10.0,
#  7.76589423648247,
#  1.9548425430778396,
#  7.332144979203799,
#  0.0,
#  7.361853832442063,
#  8.966131907308373]

# %%
pop_new = []
pop_new = map( popScale ,df_2005['Total population (millions)'] )
pop_new = list(pop_new)
pop_new
# Out:
# [10.0,
#  0.9556807797745964,
#  0.34419738044471515,
#  nan,
#  nan,
#  0.0,
#  2.2509899482180926,
#  0.22616509290283274]

# %%
gdp_new = []
gdp_new = map( gdpScale ,df_2005['GDP per capita'] )
gdp_new = list(gdp_new)
gdp_new
# Out:
# [1.2821231898837446,
#  7.250662859473792,
#  4.694829696104426,
#  nan,
#  nan,
#  0.0,
#  10.0,
#  8.18325514990822]

# %%
genderGap_new = []
genderGap_new = map( genderGapScale ,df_2005['Gender Gap Index'] )
genderGap_new = list(genderGap_new)
genderGap_new
# Out:
# [4.000000000000004,
#  2.900000000000003,
#  0.0,
#  nan,
#  nan,
#  6.600000000000008,
#  8.799999999999999,
#  10.0]

# %%
df_2005['Health Access Quality Index']
# Out:
# 0    62.0
# 1    90.2
# 2    83.0
# 3    47.8
# 4    78.0
# 5    47.2
# 6    87.3
# 7    91.2
# Name: Health Access Quality Index, dtype: float64

# %%
country_name = ['China','Japan','South Korea','North Korea','Taiwan','Mongolia',"United States",'Canada']
country_name[0]
# Out:
# 'China'

# %%
for i in range (8):
    Dict[country_name[i]]['Health True']= df_2005['Health Access Quality Index'][i]
    Dict[country_name[i]]['Healthcare Access and Quality Index']=health_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': {}, 'Civil Liberty': {4}, 'Human Development Index': {}, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 62.0}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': {}, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 90.2}
# {'Healthcare Access and Quality Index': 8.136363636363637, 'Annual CO2 Emission': {}, 'Civil Liberty': {8}, 'Human Development Index': {}, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 83.0}
# ...

# %%
for i in range (8):
    Dict[country_name[i]]['CO2 True']=df_2005['Annual CO2 emissions (per capita)'][i]
    Dict[country_name[i]]['Annual CO2 Emission']=climate_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': {}, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 62.0, 'CO2 True': 4.4159}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': {}, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511}
# {'Healthcare Access and Quality Index': 8.136363636363637, 'Annual CO2 Emission': 4.033474509093379, 'Civil Liberty': {8}, 'Human Development Index': {}, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 83.0, 'CO2 True': 10.2578}
# ...

# %%
for i in range (8):
    Dict[country_name[i]]['HDI True']=df_2005['Human Development Index'][i]
    Dict[country_name[i]]['Human Development Index']=hdi_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': 0.0, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 62.0, 'CO2 True': 4.4159, 'HDI True': 0.638}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': 9.471698113207546, 'Average Life Expectancy': {}, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511, 'HDI True': 0.889}
# ...

# %%
for i in range (8):
    Dict[country_name[i]]['Life True']=df_2005['Average Life Expectancy'][i]
    Dict[country_name[i]]['Average Life Expectancy']=life_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': 0.0, 'Average Life Expectancy': 4.682115270350566, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 62.0, 'CO2 True': 4.4159, 'HDI True': 0.638, 'Life True': 72.98}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': 9.471698113207546, 'Average Life Expectancy': 10.0, 'Total population (millions)': {}, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511, 'HDI True': 0.889, 'Life True': 81.93}
# ...

# %%
for i in range (8):
    Dict[country_name[i]]['Pop True']=df_2005['Total population (millions)'][i]
    Dict[country_name[i]]['Total population (millions)']=pop_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': 0.0, 'Average Life Expectancy': 4.682115270350566, 'Total population (millions)': 10.0, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 62.0, 'CO2 True': 4.4159, 'HDI True': 0.638, 'Life True': 72.98, 'Pop True': 1315.8}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': 9.471698113207546, 'Average Life Expectancy': 10.0, 'Total population (millions)': 0.9556807797745964, 'GDP per capita': {}, 'Gender Gap Index': {}, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511, 'HDI True': 0.889, 'Life True': 81.93, 'Pop True': 128.1}
# ...

# %%
for i in range (8):
    Dict[country_name[i]]['GDP True']=df_2005['GDP per capita'][i]
    Dict[country_name[i]]['GDP per capita']=gdp_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': 0.0, 'Average Life Expectancy': 4.682115270350566, 'Total population (millions)': 10.0, 'GDP per capita': 1.2821231898837446, 'Gender Gap Index': {}, 'Health True': 62.0, 'CO2 True': 4.4159, 'HDI True': 0.638, 'Life True': 72.98, 'Pop True': 1315.8, 'GDP True': 7204.0}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': 9.471698113207546, 'Average Life Expectancy': 10.0, 'Total population (millions)': 0.9556807797745964, 'GDP per capita': 7.250662859473792, 'Gender Gap Index': {}, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511, 'HDI True': 0.889, 'Life True': 81.93, 'Pop True': 128.1, 'GDP True': 30615.0}
# ...

# %%
for i in range (8):
    Dict[country_name[i]]['GGI True']=df_2005['Gender Gap Index'][i]
    Dict[country_name[i]]['Gender Gap Index']=genderGap_new[i]
    print(Dict[country_name[i]])
# Out:
# {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': 0.0, 'Average Life Expectancy': 4.682115270350566, 'Total population (millions)': 10.0, 'GDP per capita': 1.2821231898837446, 'Gender Gap Index': 4.000000000000004, 'Health True': 62.0, 'CO2 True': 4.4159, 'HDI True': 0.638, 'Life True': 72.98, 'Pop True': 1315.8, 'GDP True': 7204.0, 'GGI True': 0.656}
# {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': 9.471698113207546, 'Average Life Expectancy': 10.0, 'Total population (millions)': 0.9556807797745964, 'GDP per capita': 7.250662859473792, 'Gender Gap Index': 2.900000000000003, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511, 'HDI True': 0.889, 'Life True': 81.93, 'Pop True': 128.1, 'GDP True': 30615.0, 'GGI True': 0.645}
# ...

# %%
print(Dict)
# Out:
# {'China': {'Healthcare Access and Quality Index': 3.363636363636363, 'Annual CO2 Emission': 0.7257151269449413, 'Civil Liberty': {4}, 'Human Development Index': 0.0, 'Average Life Expectancy': 4.682115270350566, 'Total population (millions)': 10.0, 'GDP per capita': 1.2821231898837446, 'Gender Gap Index': 4.000000000000004, 'Health True': 62.0, 'CO2 True': 4.4159, 'HDI True': 0.638, 'Life True': 72.98, 'Pop True': 1315.8, 'GDP True': 7204.0, 'GGI True': 0.656}, 'Japan': {'Healthcare Access and Quality Index': 9.772727272727273, 'Annual CO2 Emissionn': {}, 'Civil Liberty': {8}, 'Human Development Index': 9.471698113207546, 'Average Life Expectancy': 10.0, 'Total population (millions)': 0.9556807797745964, 'GDP per capita': 7.250662859473792, 'Gender Gap Index': 2.900000000000003, 'Health True': 90.2, 'CO2 True': 10.0554, 'Annual CO2 Emission': 3.918873009761511, 'HDI True': 0.889, 'Life True': 81.93, 'Pop True': 128.1, 'GDP True': 30615.0, 'GGI True': 0.645}, 'South Korea': {'Healthca
# ...

# %%
countryindexes = pd.DataFrame.from_dict(Dict, orient = 'index')

# %%
countryindexes
# Out:
#                Healthcare Access and Quality Index  Annual CO2 Emission  \
# China                                     3.363636             0.725715
# Japan                                     9.772727             3.918873
# South Korea                               8.136364             4.033475
# North Korea                               0.136364             0.000000
# Taiwan                                    7.000000             4.870111
# Mongolia                                  0.000000             0.146876
# United States                             9.113636            10.000000
# Canada                                   10.000000             8.362569
#
#               Civil Liberty  Human Development Index  Average Life Expectancy  \
# China                   {4}                 0.000000                 4.682115
# Japan                   {8}                 9.471698                10.000000
# South Korea             {8}                 8.377358                 7.765894
# ...

# %%
def getItem(s):
    for x in s:
        return x
    
countryindexes['Civil Liberty'] = countryindexes['Civil Liberty'].apply(lambda x: getItem(x))

# %%
countryindexes.reset_index(inplace=True)
countryindexes= countryindexes.rename(columns = {'index':'Country'})
countryindexes
# Out:
#          Country  Healthcare Access and Quality Index  Annual CO2 Emission  \
# 0          China                             3.363636             0.725715
# 1          Japan                             9.772727             3.918873
# 2    South Korea                             8.136364             4.033475
# 3    North Korea                             0.136364             0.000000
# 4         Taiwan                             7.000000             4.870111
# 5       Mongolia                             0.000000             0.146876
# 6  United States                             9.113636            10.000000
# 7         Canada                            10.000000             8.362569
#
#    Civil Liberty  Human Development Index  Average Life Expectancy  \
# 0              4                 0.000000                 4.682115
# 1              8                 9.471698                10.000000
# 2              8                 8.377358                 7.765894
# ...

# %%
df_nodes = pd.read_csv("nodes.csv")
df_nodes.dtypes
# Out:
# Unnamed: 0       int64
# SubContinent    object
# Country         object
# Weight           int64
# dtype: object

# %%
df_nodes.columns
# Out:
# Index(['Unnamed: 0', 'SubContinent', 'Country', 'Weight'], dtype='object')

# %%
countryindexes.dtypes
for x in countryindexes.Country:
    print(type(x))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
for x in df_nodes.Country:
    print(type(x))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df_final = df_nodes.merge(countryindexes, on = 'Country', how = "left")
df_final
# Out:
#     Unnamed: 0      SubContinent              Country    Weight  \
# 0            0     North America        United States   8695577
# 1            1     North America               Canada   1415707
# 2            2     Latin America        Latin America   7703933
# 3            3            Africa               Africa  11674618
# 4            4            Europe               Europe  14025778
# 5            5  Fmr Soviet Union     Fmr Soviet Union   4736991
# 6            6         West Asia            West Asia   9528478
# 7            7        South Asia           South Asia  11528268
# 8            8         East Asia  Hong Kong and Macao   2292230
# 9            9         East Asia                China   1991399
# 10          10         East Asia                Japan    472167
# 11          11         East Asia          North Korea     54103
# 12          12         East Asia          South Korea    773143
# 13          13         East Asia             Mongolia     28142
# ...

# %%
df_final.to_json("nodes_vfinal.json", orient = "index")
